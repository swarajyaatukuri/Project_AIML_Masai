# %%
print("Hello World")
# Out:
# Hello World

# %%
name='Masai'
age=28
height=5.3
is_student=1
print(f"Name: {name}| age: {age}| Height:{height}| Student: {is_student}")
# Out:
# Name: Masai| age: 28| Height:5.3| Student: 1
